# %% [markdown]
# <a href="https://colab.research.google.com/github/JuiiiDixit/Jui-Dixit-EDA-AllExpts-25070123059/blob/main/BASICS_OF_PYTHON.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Exploratory Data Analysis
# ##Basics of Python
# ### Expt-1

# %% [markdown]
# # New Section

# %%
print("I am learning python")
# Out:
# I am learning python

# %%
#Test code
print('I am at Symbiosis')
# Out:
# I am at Symbiosis

# %%
#Understanding data types
x=10
y=3.14
z="Python"
A=True
C=3+2j

print(type(x))
print(type(y))
print(type(z))
print(type(A))
print(type(C))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
# <class 'complex'>

# %%
#Many values to multiple variables
x, y, z = "Orange", "Banana", "Cherry"
print(x)
print(y)
print(z)
# Out:
# Orange
# Banana
# Cherry

# %%
name = input("Enter your name:")
print(name, input)
# Out:
# Enter your name:Robin
# Robin <bound method Kernel.raw_input of <google.colab._kernel.Kernel object at 0x7823490cd9a0>>

# %%
#Variables
x=5
y="Hello World!"
print(x)
print(y)
# Out:
# 5
# Hello World!

# %%
print("Hello"); print("How are you"); print("I'm fine!")
# Out:
# Hello
# How are you
# I'm fine!

# %%
print("This will cause an error") print("Now")
# Out:
#   File "/tmp/ipython-input-2061167881.py", line 1
#     print("This will cause an error") print("Now")
#                                       ^
# SyntaxError: invalid syntax

# %%
#Case sensitivity
a = 4
A = "Sally"
print(a)
print(A)
# Out:
# 4
# Sally

# %%
#Basic arithmetic operations
a = 10
b = 5
print("Addition:", a + b)
print("Subtraction:", a - b)
print("Multiplication:", a*b)
print("Division:", a/b)
# Out:
# Addition: 15
# Subtraction: 5
# Multiplication: 50
# Division: 2.0

# %%
#Taking input from user
name = input("Enter your name:")
print("Hello", name)
# Out:
# Enter your name:Jui
# Hello Jui

# %%
#Simple calculator
a = int(input("Enter first number:"))
b = int(input("Enter second number:"))
print("Sum:", a + b)
print("Difference:", a - b)
print("Product:", a * b)
print("Quotient:", a/b)
# Out:
# Enter first number:2
# Enter second number:3
# Sum: 5
# Difference: -1
# Product: 6
# Quotient: 0.6666666666666666

# %%
#Write a python program to find the area of a circle
r = float(input("Enter the radius of the circle:"))
area = 3.14 * r * r
print("Area pf circle:", area)
# Out:
# Enter the radius of the circle:20
# Area pf circle: 1256.0

# %%
#Python booleans
print(10 > 9)
print(10 == 9)
print(10 < 9)
# Out:
# True
# False
# False

# %%
#Print a message based on if the condition is true or false
a = 200
b = 33
if b > a:
  print("b is greater than a")
else:
    print("b is not greater than a")
# Out:
# b is not greater than a
