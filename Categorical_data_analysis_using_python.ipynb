# %% [markdown]
# <a href="https://colab.research.google.com/github/JuiiiDixit/Jui-Dixit-EDA-AllExpts-25070123059/blob/main/Categorical_data_analysis_using_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Experiment 11: Categorical data analysis using python
# #Name: Jui Dixit
# #Class: ENTC A
# #PRN: 25070123059

# %%
import pandas as pd
data={
'Order_ID':['01','02','03','04','05','06','07','08','09','010'],
       'Category':['Furniture','Office Supplies','Furniture','Technology','Technology','Furniture','Office Supplies','Furniture','Technology','Technology'],
       'Payment_Mode':['COD','COD','UPI','COD','UPI','COD','COD','UPI','COD','UPI'],
       'Delivery_Type':['Express','Standard','Express','Standard','Express','Standard','Express','Standard','Express','Standard'],
       'Customer_Type':['New','Returning','New','Returning','New','New','Returning','New','Returning','New']
}
df=pd.DataFrame(data)
df
# Out:
#   Order_ID         Category Payment_Mode Delivery_Type Customer_Type
# 0       01        Furniture          COD       Express           New
# 1       02  Office Supplies          COD      Standard     Returning
# 2       03        Furniture          UPI       Express           New
# 3       04       Technology          COD      Standard     Returning
# 4       05       Technology          UPI       Express           New
# 5       06        Furniture          COD      Standard           New
# 6       07  Office Supplies          COD       Express     Returning
# 7       08        Furniture          UPI      Standard           New
# 8       09       Technology          COD       Express     Returning
# 9      010       Technology          UPI      Standard           New

# %%
#Frequency Count
#Count how many orders in each category
print(df['Category'].value_counts())
print( df['Payment_Mode'].value_counts())
print(df['Delivery_Type'].value_counts())
# Out:
# Category
# Furniture          4
# Technology         4
# Office Supplies    2
# Name: count, dtype: int64
# Payment_Mode
# COD    6
# UPI    4
# Name: count, dtype: int64
# Delivery_Type
# Express     5
# Standard    5
# Name: count, dtype: int64

# %%
#Unique Values
#Display all unique categories
print(df['Category'].unique())
print(df['Payment_Mode'].unique())
print(df['Delivery_Type'].unique())
print(df['Customer_Type'].unique())
# Out:
# ['Furniture' 'Office Supplies' 'Technology']
# ['COD' 'UPI']
# ['Express' 'Standard']
# ['New' 'Returning']

# %%
#Number of Unique Values
print(df['Category'].nunique())
print(df['Payment_Mode'].nunique())
print(df['Delivery_Type'].nunique())
print(df['Customer_Type'].nunique())
# Out:
# 3
# 2
# 2
# 2

# %%
#Cross Tabulation
#Category vs Payment Method
print(pd.crosstab(df['Category'],df['Payment_Mode']))
# Out:
# Payment_Mode     COD  UPI
# Category
# Furniture          2    2
# Office Supplies    2    0
# Technology         2    2

# %%
#Cross Tabulation
#Category vs Payment Method
print(pd.crosstab(df['Category'],df['Payment_Mode']))
# Out:
# Payment_Mode     COD  UPI
# Category
# Furniture          2    2
# Office Supplies    2    0
# Technology         2    2

# %%
#Cross Tabulation
#Category vs Payment Method
print(pd.crosstab(df['Category'],df['Payment_Mode']))
# Out:
# Payment_Mode     COD  UPI
# Category
# Furniture          2    2
# Office Supplies    2    0
# Technology         2    2

# %%
#Filtering Data
#Orders from Electronics Category
print(df[df['Category']=='Furniture'])
# Out:
#   Order_ID   Category Payment_Mode Delivery_Type Customer_Type
# 0       01  Furniture          COD       Express           New
# 2       03  Furniture          UPI       Express           New
# 5       06  Furniture          COD      Standard           New
# 7       08  Furniture          UPI      Standard           New

# %%
#Grouping
#Orders by Category and Payment Method
print(df.groupby('Category')['Payment_Mode'].value_counts())
# Out:
# Category         Payment_Mode
# Furniture        COD             2
#                  UPI             2
# Office Supplies  COD             2
# Technology       COD             2
#                  UPI             2
# Name: count, dtype: int64

# %%
#Sorting Data
sorted_df=df.sort_values(by='Category')
print(sorted_df)
# Out:
#   Order_ID         Category Payment_Mode Delivery_Type Customer_Type
# 0       01        Furniture          COD       Express           New
# 2       03        Furniture          UPI       Express           New
# 5       06        Furniture          COD      Standard           New
# 7       08        Furniture          UPI      Standard           New
# 1       02  Office Supplies          COD      Standard     Returning
# 6       07  Office Supplies          COD       Express     Returning
# 3       04       Technology          COD      Standard     Returning
# 4       05       Technology          UPI       Express           New
# 8       09       Technology          COD       Express     Returning
# 9      010       Technology          UPI      Standard           New
